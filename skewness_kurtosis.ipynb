# %%
exec(open('Template1.py').read())
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# %load http://matplotlib.org/mpl_examples/pylab_examples/contour_demo.py
# Out:
#                              M1     M2     M3     M4     M5     M6     M7  \
# COUNTRY ID          YEAR
# AC      ACW00011604 1961  -1.42   1.83   4.19   7.20  10.75  15.46  15.17
#                     1962   0.60   0.32  -2.07   5.82   8.55  13.28  14.57
#                     1963  -7.66  -6.06  -1.52   4.88  11.71  15.74  15.67
#                     1964   0.09  -1.38   0.02   6.85  11.66  13.89  14.53
#                     1965  -0.09  -1.58  -0.15   5.37   9.34  14.47  14.34
# ...                         ...    ...    ...    ...    ...    ...    ...
# ZI      ZIXLT622116 1966  21.80  20.40  18.40  16.90  14.30  12.80  12.10
#                     1967  21.10  19.90  18.90  19.20  15.10  13.50  11.00
#                     1968  21.80  20.00  19.30  18.20  15.60  10.80  13.70
#                     1969  20.90  21.50  19.50  18.30  14.10  13.10  11.60
#                     1970  20.70  19.90  19.30  17.20  15.60  13.30  13.30
#
#                              M8     M9    M10    M11    M12
# COUNTRY ID          YEAR
# AC      ACW00011604 1961  14.28  13.60  11.21   4.57  -0.92
#                     1962  13.40  11.10   9.41   2.70  -1.79
#                     1963  15.43  12.79   8.87   5.13  -1.61
#                     1964  15.04  11.68   7.35   4.93   0.59
#                     1965  14.24  13.24   9.21  -0.22  -2.31
# ...                         ...    ...    ...    ...    ...
# ZI      ZIXLT622116 1966  14.60  17.70  19.80  20.90  21.10
#                     1967  13.80  16.60  20.80  19.90  19.10
#                     1968  16.30  17.60  21.80  18.40  20.70
#                     1969  14.60  17.80  21.00  20.40  19.10
#                     1970  15.40  20.40  20.30  21.30  21.50
#
# [1457908 rows x 12 columns]
#                      LATITUDE  LONGITUDE  ELEVATION                  NAME
# COUNTRY ID
# AC      ACW00011604     57.77      11.87       18.0                  SAVE
# AE      AE000041196     25.33      55.52       34.0    SHARJAH_INTER_AIRP
#         AEM00041184     25.62      55.93       31.0   RAS_AL_KHAIMAH_INTE
#         AEM00041194     25.25      55.36       10.4            DUBAI_INTL
#         AEM00041216     24.43      54.47        3.0  ABU_DHABI_BATEEN_AIR
# ...                       ...        ...        ...                   ...
# ZI      ZI000067983    -20.20      32.62     1132.0              CHIPINGE
#         ZI000067991    -22.22      30.00      457.0            BEITBRIDGE
#         ZIXLT371333    -17.83      31.02     1471.0      HARARE_BELVEDERE
#         ZIXLT443557    -18.98      32.45     1018.0            GRAND_REEF
#         ZIXLT622116    -19.43      29.75     1411.0                 GWELO
#
# [27850 rows x 4 columns]

# %%
import numpy as np

station_labels = (
        'BR027794310',
        'BRM00082994',
        'RSM00026063',
        'RSM00027612',
        'WAXLT711578',
        'USW00094728', 
        'USW00023234',
        'RSM00032540',
        'RSM00031960',
        'RSM00037099'
        )

#0#BR027794310  -3.7000  -40.3500   83.0 SOBRAL
#1#BRM00082994  -9.6600  -35.7000   64.5 MACEIO 
#2#RSM00026063  59.9667   30.3000    3.0 ST_PETERSBURG 
#3#RSM00027612  55.8331   37.6167  156.0 MOSCOW 
#4#WAXLT711578 -22.9400   14.4400 9999.0 WALFISCH_BAY  
#5#USW00094728  40.7789  -73.9692   39.6 NEW_YORK_CNTRL_PK_TWR 
#6#USW00023234  37.6197 -122.3647    2.4 SAN_FRANCISCO_INTL_AP
#7#RSM00032540  52.9831  158.6500   32.0 PETROPAVLOVSK_KAMCHATSKIJ
#8#RSM00031960  43.1167  131.9330  187.0 VLADIVOSTOK
#9#RSM00037099  43.5800   39.7700   57.0 SOTCHI


idx_slice = pd.IndexSlice[:, station_labels, :]
cdf_stations = mdf.loc[idx_slice, :]

display(cdf_stations)
# Out:
#                             M1     M2    M3    M4    M5    M6    M7    M8  \
# COUNTRY ID          YEAR
# BR      BR027794310 1924   NaN    NaN   NaN 27.30 27.05 26.20 26.20 27.30
#                     1925 27.90 126.40 26.95 27.15 26.90 27.20 28.05 28.90
#                     1926 28.45  27.50 27.60 27.65 27.55 27.15 28.09 28.25
#                     1927   NaN  28.60 27.80   NaN 27.30 26.85 27.34 28.65
#                     1928 29.40  29.60 27.84 27.95   NaN 27.85 28.25 28.95
# ...                        ...    ...   ...   ...   ...   ...   ...   ...
# RS      RSM00037099 2015  7.32   9.60 10.22 10.77 17.21 22.01 23.40 26.06
#                     2016  5.39   9.97 11.05 14.49 16.89 22.41 24.15 26.26
#                     2017  5.82   6.31 10.73 12.47 16.52 20.94 24.71 26.33
#                     2018  7.62   9.51 11.73 14.63 20.24 23.66 25.09 25.44
#                     2019  8.36   8.20  8.08 13.21 19.27 24.75   NaN   NaN
#
#                             M9   M10   M11   M12
# COUNTRY ID          YEAR
# BR      BR027794310 1924 28.75   NaN   NaN 28.70
#                     1925   NaN 29.95 29.90 29.75
#                     1926 29.40 29.75   NaN 29.70
#                     1927   NaN 30.30 30.60 30.45
#                     1928 29.95 30.25 30.15 30.75
# ...                        ...   ...   ...   ...
# RS      RSM00037099 2015 24.70 16.64 12.45  7.32
#                     2016 20.22 15.58 11.61  4.41
#                     2017 23.36 16.00 11.93 10.38
#                     2018 21.87 17.80 12.91  9.13
#                     2019   NaN   NaN   NaN   NaN
#
# [1307 rows x 12 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sb
import pandas as pd

import scipy.stats as stats
from scipy.stats import kurtosis

from sklearn.linear_model import LinearRegression

#select one station
idx_slice = pd.IndexSlice[:, station_labels[6], :]
cdf = cdf_stations.loc[idx_slice, :]

def temperature_scatterplot(station_labels, data, msf):
        
        months = data.columns
        msf = msf
        
        fig, our_axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
        monthly_axes = [ax for ax_row in our_axes for ax in ax_row]
        
        fig.subplots_adjust( hspace=0.4) 
        station_index = data.index[0][0:2]
        fig.suptitle(f'ID {station_index[1]}\n' + msf.loc[station_index,:].to_string(index = True))
        
        for i, month in enumerate(months):
            data_m = data.iloc[:,i].reset_index(level = 2, drop = False).reset_index(drop=True)
            s = sb.scatterplot(data = data_m,  x="YEAR", y=data_m.columns[1], ax = monthly_axes[i])
            s.set_xlabel('Year')
            s.set_ylabel('Temperature')
            s.set_title('Month ' + data_m.columns[1])
            
            data_m_drop_na = data_m.dropna()
            x = np.array(data_m_drop_na.YEAR).reshape((-1, 1))
            y = np.array(data_m_drop_na[data_m_drop_na.columns[1]])
            model = LinearRegression().fit(x, y)
            r_sq = model.score(x, y)
            y_pred = model.predict(x)
            monthly_axes[i].plot(x, y_pred, 'r')
            s.set_xlabel(f'Year, coefficient of determination = {r_sq:5.2f}')

        return ()

def temperature_density(station_labels, data, msf):
        
        months = data.columns
        msf = msf
        
        fig, our_axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
        monthly_axes = [ax for ax_row in our_axes for ax in ax_row]
        
        fig.subplots_adjust( hspace=0.2) 
        station_index = data.index[0][0:2]
        fig.suptitle(f'ID {station_index[1]}\n' + msf.loc[station_index,:].to_string(index = True))
        
        for i, month in enumerate(months):
            data_m = data.iloc[:,i].reset_index(drop=True)
            s = sb.kdeplot(data = data_m, ax = monthly_axes[i])
        return ()

def skewness_kurtosis_histplot(station_labels, data, msf):
        
        months = data.columns
        msf = msf
        
        fig, our_axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
        monthly_axes = [ax for ax_row in our_axes for ax in ax_row]
        
        fig.subplots_adjust( hspace=0.3)
        station_index = data.index[0][0:2]
        fig.suptitle(f'ID {station_index[1]}\n' + msf.loc[station_index,:].to_string(index = True))
        
        for i, month in enumerate(months):
            data_m = data.iloc[:,i].dropna()
            s = sb.histplot(data = data_m,  kde=True, ax = monthly_axes[i])
            kur = data_m.kurtosis()
            skw = data_m.skew()
            s.set_xlabel(f'Temperature, kurtosis = {kur:5.2f}, skewness = {skw:4.2f}')
            s.set_ylabel('Count')
            s.set_title('Month ' + months[i])
        return ()

#Station statistics
   
temperature_scatterplot(station_labels,cdf, msf)
temperature_density(station_labels,cdf, msf)
skewness_kurtosis_histplot(station_labels,cdf, msf)
plt.show()
